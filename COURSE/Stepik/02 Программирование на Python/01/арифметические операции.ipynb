# %%
2+5
# Out:
# 7

# %%
10-5
# Out:
# 5

# %%
6*2
# Out:
# 12

# %% [markdown]
# Проверка маркдаун

# %% [markdown]
# <div style="width: 200px;">![i_get-started.svg](attachment:i_get-started.svg)</div>

# %% [markdown]
# ![2018-06-25_11-38-17.png](attachment:2018-06-25_11-38-17.png)

# %%
1234556789000 * 10000000000000000000000
# Out:
# 12345567890000000000000000000000000

# %%
3+5*4
# Out:
# 23

# %%
(3+5)*4
# Out:
# 32

# %%
11111*1111111
# Out:
# 12345554321

# %% [markdown]
# Целочисленное деление

# %%
42//8
# Out:
# 5

# %% [markdown]
# Остаток от деления

# %%
42%8
# Out:
# 2

# %%
42/(4+2*(-2))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-1cc156a7f7e2> in <module>()
# ----> 1 42/(4+2*(-2))
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Возведене в степень

# %%
2**5
# Out:
# 32

# %%
2014**14
# Out:
# 18064773765607550801425251468864907833685590016

# %%
-(42)
# Out:
# -42

# %%
+(42)
# Out:
# 42

# %%
+-+42
# Out:
# -42

# %%
-*42
# Out:
#   File "<ipython-input-18-761874de80cf>", line 1
#     -*42
#      ^
# SyntaxError: invalid syntax

# %%
print("test")
print("test01")
-*42
# Out:
#   File "<ipython-input-19-b828399478b7>", line 3
#     -*42
#      ^
# SyntaxError: invalid syntax

# %%
5//0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-20-83598ca529be> in <module>()
# ----> 1 5//0
#
# ZeroDivisionError: integer division or modulo by zero
